# %% [markdown]
# # Watermark Fortress Analysis
#
# This notebook loads the benchmark summary and inspects the adaptive-vs-static deltas.

# %%
import json
from pathlib import Path

payload = json.loads(Path('../results/benchmark_summary.json').read_text())
payload['summary']
